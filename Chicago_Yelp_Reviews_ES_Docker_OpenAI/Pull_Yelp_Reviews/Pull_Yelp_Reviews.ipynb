# %%
#Import Elascticsearch and helpers from  elasticsearch

from elasticsearch import Elasticsearch
from pprint import pprint
from openai import OpenAI
import pandas as pd
import openai
import json

es = Elasticsearch(['http://localhost:9200'])

# Initialize OpenAI client with API key
client = OpenAI(api_key="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")


# Define model and embedding function


EMBEDDING_MODEL = "text-embedding-ada-002"
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
# Pretty print function for businesses reviewed

def pretty_response_business(response):
    for hit in response['hits']['hits']:
        id = hit['_id']
        score = hit['_score']
        title = hit['_source']['name']
        closed = hit['_source']['closed']
        review_count = hit['_source']['review_count']
        categories = hit['_source']['categories']
        rating = hit['_source']['rating']
        coordinates = hit['_source']['coordinates']
        transactions = hit['_source']['transactions']
        location = hit['_source']['location']
        phone = hit['_source']['phone']
        
        pretty_output = (
            f"\nID: {id}\nScore: {score}\nTitle: {title}\nClosed: {closed}\nReview Count: {review_count}\n"
            f"Categories: {categories}\nRating: {rating}\nCoordinates: {coordinates}\n"
            f"Transactions: {transactions}\nLocation: {location}\nPhone: {phone}"
        )
        print(pretty_output)


# Pretty print function for reviews per business

def pretty_response_reviews(response):
    # Create a dictionary to store reviews based on business ID and Biz URL
    business_reviews = {}

    for hit in response['hits']['hits']:
        business_id = hit['_source']['business_id']
        biz_url = hit['_source']['biz_url']
        reviews = hit['_source']['reviews']

        # Check if the business ID and Biz URL combination is already in the dictionary
        if (business_id, biz_url) not in business_reviews:
            business_reviews[(business_id, biz_url)] = []

        if reviews:
            if isinstance(reviews, list):  # Check if 'reviews' is a list
                # Append each review to the corresponding business ID and Biz URL in the dictionary
                business_reviews[(business_id, biz_url)].extend(reviews)
            else:
                # If 'reviews' is not a list, assume it's a single review dictionary
                business_reviews[(business_id, biz_url)].append(reviews)

    # Print the results
    for (business_id, biz_url), reviews in business_reviews.items():
        pretty_output = f"\nBusiness ID: {business_id}\nBiz URL: {biz_url}"

        for review_info in reviews:
            pretty_output += (
                f"\n\n  Review ID: {review_info['id']}\n  Review URL: {review_info['url']}\n"
                f"  Review Text: {review_info['text']}\nReview Rating: {review_info['rating']}\n"
                f"  Review Time Created: {review_info['time_created']}\n"
                f"  User Details: {review_info['user']}\n"
            )

        print(pretty_output)

# %%
#Searching based on chicago_yelp_bussinesses_reviewed index 

# Define question
question = 'Bob’s Pizza'

question_embedding = get_embedding(question, model=EMBEDDING_MODEL)

response = es.search(
  index="chicago_yelp_bussinesses_reviewed",
  knn={
      "field": "chicago_yelp_businesses_vector",  
      "query_vector": question_embedding,
      "k": 10,
      "num_candidates": 100
    }
)

pretty_response_business(response)
# Out:
# ID: H1FcedlGJtsmA8efpypFow
# Score: 0.98816776
# Title: Bob’s Pizza
# Closed: False
# Review Count: 8
# Categories: [{'alias': 'pizza', 'title': 'Pizza'}]
# Rating: 5.0
# Coordinates: {'latitude': 41.8891862295013, 'longitude': -87.6492763290888}
# Transactions: ['pickup', 'delivery']
# Location: {'address1': '838 W Kinzie St', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60642', 'country': 'US', 'state': 'IL', 'display_address': ['838 W Kinzie St', 'Chicago, IL 60642']}
# Phone:
#
# ID: 511flt1E6niG0sK5FkX_fQ
# Score: 0.93301356
# Title: Five Squared Pizza
# Closed: False
# Review Count: 29
# Categories: [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}]
# Rating: 4.9
# Coordinates: {'latitude': 41.906137, 'longitude': -87.648434}
# Transactions: ['delivery', 'pickup']
# Location: {'address1': '1332 N Halsted St', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60612', 'country': 'US', 'state': 'IL', 'display_address': ['1332 N Halsted St', 'Chicago, IL 60612']}
# Phone:
#
# ID: Bi-6UBXdNKUOsNAcvhuucA
# Score: 0.91900295
# Title: Te'amo Boba Bar
# Closed: False
# Review Count: 20
# Categories: [{'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'customcakes', 'title': 'Custom Cakes'}]
# Rating: 4.9
# Coordinates: {'latitude': 41.897991, 'longitude': -87.622916}
# Transactions: ['delivery', 'pickup']
# Location: {'address1': '835 N Michigan Ave', 'address2': 'Fl 2', 'address3': '', 'city': 'Chicago', 'zip_code': '60611', 'country': 'US', 'state': 'IL', 'display_address': ['835 N Michigan Ave', 'Fl 2', 'Chicago, IL 60611']}
# Phone:
#
# ID: YrC3D7DVIQvGVFWBUQw4-w
# Score: 0.9182066
# Title: Chef Ciccio
# Closed: False
# Review Count: 23
# Categories: [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# Rating: 4.8
# Coordinates: {'latitude': 41.89170724874642, 'longitude': -87.60848070057254}
# Transactions: ['pickup', 'delivery']
# Location: {'address1': '600 E Grand Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60611', 'country': 'US', 'state': 'IL', 'display_address': ['600 E Grand Ave', 'Chicago, IL 60611']}
# Phone: +13128775639
#
# ID: Nq5521Fiu-xm1III-RdG_Q
# Score: 0.9139493
# Title: Blackwood BBQ
# Closed: False
# Review Count: 5
# Categories: [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# Rating: 5.0
# Coordinates: {'latitude': 41.89483, 'longitude': -87.62118}
# Transactions: []
# Location: {'address1': '251 E Huron St', 'address2': 'Feinberg Pavilion - Fl 2', 'address3': None, 'city': 'Chicago', 'zip_code': '60611', 'country': 'US', 'state': 'IL', 'display_address': ['251 E Huron St', 'Feinberg Pavilion - Fl 2', 'Chicago, IL 60611']}
# Phone:
#
# ID: F7MrseVv7HE0l8TTjkxypw
# Score: 0.9136434
# Title: Bartleby's Ice Cream Cakes
# Closed: False
# Review Count: 48
# Categories: [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'customcakes', 'title': 'Custom Cakes'}]
# Rating: 4.8
# Coordinates: {'latitude': 41.8816606, 'longitude': -87.6926257}
# Transactions: []
# Location: {'address1': '3720 N Lincoln Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60613', 'country': 'US', 'state': 'IL', 'display_address': ['3720 N Lincoln Ave', 'Chicago, IL 60613']}
# Phone: +18722561559
#
# ID: JEuVR4mok0YB8DNLtGEDBg
# Score: 0.9130397
# Title: Bhoomi Modern Indian Grill
# Closed: False
# Review Count: 136
# Categories: [{'alias': 'indpak', 'title': 'Indian'}]
# Rating: 4.7
# Coordinates: {'latitude': 41.8831, 'longitude': -87.62868}
# Transactions: ['delivery', 'pickup']
# Location: {'address1': '15 W Washington St', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60602', 'country': 'US', 'state': 'IL', 'display_address': ['15 W Washington St', 'Chicago, IL 60602']}
# Phone: +13122247866
#
# ID: df8qtT0awnBHPzaR88w_0w
# Score: 0.9114574
# Title: Jersey Mike's Subs
# Closed: False
# Review Count: 9
# Categories: [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# Rating: 5.0
# Coordinates: {'latitude': 41.92499597261036, 'longitude': -87.65938}
# Transactions: ['delivery', 'pickup']
# Location: {'address1': '1223 W Fullerton Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60614', 'country': 'US', 'state': 'IL', 'display_address': ['1223 W Fullerton Ave', 'Chicago, IL 60614']}
# Phone: +13123006995
#
# ID: soRFbCCBxvunxaLNTs7aIQ
# Score: 0.91140735
# Title: Italian Homemade Company
# Closed: False
# Review Count: 25
# Categories: [{'alias': 'pastashops', 'title': 'Pasta Shops'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'piadina', 'title': 'Piadina'}]
# Rating: 4.9
# Coordinates: {'latitude': 41.88662, 'longitude': -87.65168}
# Transactions: ['delivery', 'pickup']
# Location: {'address1': '947 W Fulton Market St', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60607', 'country': 'US', 'state': 'IL', 'display_address': ['947 W Fulton Market St', 'Chicago, IL 60607']}
# Phone: +13122650697
#
# ID: lxrCrU1PRB-lIpwBA7wtcw
# Score: 0.91121364
# Title: Masa Madre
# Closed: False
# Review Count: 9
# Categories: [{'alias': 'bakeries', 'title': 'Bakeries'}]
# Rating: 4.9
# Coordinates: {'latitude': 41.88388, 'longitude': -87.70583}
# Transactions: ['delivery']
# Location: {'address1': '135 N Kedzie Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60612', 'country': 'US', 'state': 'IL', 'display_address': ['135 N Kedzie Ave', 'Chicago, IL 60612']}
# Phone: +18722018230

# %%
#Searching based on chicago_yelp_reviews_per_business index 

# Define question
question = 'Pizza'

question_embedding = get_embedding(question, model=EMBEDDING_MODEL)

response = es.search(
  index="chicago_yelp_reviews_per_business",
  knn={
      "field": "reviews.content_vector",  
      "query_vector": question_embedding,
      "k": 10,
      "num_candidates": 100
    }
)

pretty_response_reviews(response)
# Out:
# Business ID: 511flt1E6niG0sK5FkX_fQ
# Biz URL: https://www.yelp.com/biz/five-squared-pizza-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: c23ASiIG19KmFO35UJ6TNQ
#   Review URL: https://www.yelp.com/biz/five-squared-pizza-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=c23ASiIG19KmFO35UJ6TNQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: With gourmet Detroit-style pizza in a city known for its deep-dish, Five Squared Pizza holds their own weight.
#
# Ordering a small cube shaped pizza over...
# Review Rating: 5
#   Review Time Created: 2024-01-26 12:46:34
#   User Details: {'id': 'xZWSNdoEJwnCSI9pM37ziA', 'profile_url': 'https://www.yelp.com/user_details?userid=xZWSNdoEJwnCSI9pM37ziA', 'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/QZg9lZ6RmgaLNXXpcd5YiQ/o.jpg', 'name': 'Eliana J.'}
#
#
#   Review ID: w-yaoIut609hrbRZUOUTig
#   Review URL: https://www.yelp.com/biz/five-squared-pizza-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=w-yaoIut609hrbRZUOUTig&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: Really good pizza! Love that you can choose 4 different flavors in a box. Basically, you order online, come to the location listed, and text that you've...
# Review Rating: 5
#   Review Time Created: 2024-02-23 17:47:31
#   User Details: {'id': 'i6JiLIFlXWcKVkWJsUzO8w', 'profile_url': 'https://www.yelp.com/user_details?userid=i6JiLIFlXWcKVkWJsUzO8w', 'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/r3JVYHNETSg7SwLVIcHoCA/o.jpg', 'name': 'Asad R.'}
#
#
# Business ID: H1FcedlGJtsmA8efpypFow
# Biz URL: https://www.yelp.com/biz/bob-s-pizza-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: B7OlrjhkjMHe9vFJJ-ppxw
#   Review URL: https://www.yelp.com/biz/bob-s-pizza-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=B7OlrjhkjMHe9vFJJ-ppxw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: we ordered via Uber Eats and we were so happy with Bob's as an awesome takeout option! the pizzas come cut into slices, but they were large enough that the...
# Review Rating: 5
#   Review Time Created: 2022-06-30 11:28:11
#   User Details: {'id': '8m0bGVCGPlYcQA710Ls4cQ', 'profile_url': 'https://www.yelp.com/user_details?userid=8m0bGVCGPlYcQA710Ls4cQ', 'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/zYvKwjWDW9yuEWkGUpn7Ow/o.jpg', 'name': 'Ellie D.'}
#
#
#   Review ID: mKu00cGNB1fxE2eyNtWWww
#   Review URL: https://www.yelp.com/biz/bob-s-pizza-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=mKu00cGNB1fxE2eyNtWWww&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: Roasted Chicken and Kimchi pizza feels like, yes, something you can get in the West Loop, but I'm gonna say that Bobs pizza does it better than any...
# Review Rating: 5
#   Review Time Created: 2020-09-22 20:16:48
#   User Details: {'id': 'zuKR4B3CdrnA4HpqFvaVJQ', 'profile_url': 'https://www.yelp.com/user_details?userid=zuKR4B3CdrnA4HpqFvaVJQ', 'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/TNxycvkO5WS91HgbYkItyA/o.jpg', 'name': 'Chris R.'}
#
#
# Business ID: JEuVR4mok0YB8DNLtGEDBg
# Biz URL: https://www.yelp.com/biz/bhoomi-modern-indian-grill-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: Zn70UlqtUv56W5Cc_sm-lA
#   Review URL: https://www.yelp.com/biz/bhoomi-modern-indian-grill-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=Zn70UlqtUv56W5Cc_sm-lA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: Ordered delivery via Uber, healthy-ish Indian food. Food was well seasoned and flavorful. The lamb Bhoomi burger was tasty and the rice bowl with beef was...
# Review Rating: 5
#   Review Time Created: 2023-11-25 12:32:39
#   User Details: {'id': 'Jr4_KaHdT0fThdSTCsI_4w', 'profile_url': 'https://www.yelp.com/user_details?userid=Jr4_KaHdT0fThdSTCsI_4w', 'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/oU0jPqKCOUalI9Be2-Cq6A/o.jpg', 'name': 'Karan H.'}
#
#
# Business ID: XEzBVYd2gmuWKOpQggbKIg
# Biz URL: https://www.yelp.com/biz/firenze-italian-street-food-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: TK0qYtmqwUCQqCNbzBEgFg
#   Review URL: https://www.yelp.com/biz/firenze-italian-street-food-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=TK0qYtmqwUCQqCNbzBEgFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: I ordered the spicy soppressata sandwich for lunch. The ingredients were fresh and I loved the bite of spiciness followed by the creaminess of the ricotta...
# Review Rating: 4
#   Review Time Created: 2023-10-03 15:48:05
#   User Details: {'id': 'GS5Dk7Q-yCkFYdBmmI1Yvw', 'profile_url': 'https://www.yelp.com/user_details?userid=GS5Dk7Q-yCkFYdBmmI1Yvw', 'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/l_r-vUarQLlRYSV2nFhDOw/o.jpg', 'name': 'Samuel A.'}
#
#
#   Review ID: ri4ZkEdP8mUX8CWIP5PQkg
#   Review URL: https://www.yelp.com/biz/firenze-italian-street-food-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=ri4ZkEdP8mUX8CWIP5PQkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: The spicy soppressata and the chicken pesto are both amazing. Tons of flavor, surprisingly filling, and it justifies the price which might seem more than...
# Review Rating: 5
#   Review Time Created: 2023-06-26 08:16:24
#   User Details: {'id': '4HvIzTHB9o-aI6M8IO3SPQ', 'profile_url': 'https://www.yelp.com/user_details?userid=4HvIzTHB9o-aI6M8IO3SPQ', 'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/dzklHrKzGIIAuWfZi_G5Qw/o.jpg', 'name': 'Lucas W.'}
#
#
# Business ID: xe4ZeL8Cv1IDPJDlsxO8cQ
# Biz URL: https://www.yelp.com/biz/pig-and-fire-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: WXD6DG3k9V34FQjQzNAiJw
#   Review URL: https://www.yelp.com/biz/pig-and-fire-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=WXD6DG3k9V34FQjQzNAiJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: Two of my favorite things! Pig and fire!!!! How could I go wrong? That's right...I can't!
#
# I recently ordered some delicious eats from their weekend popup...
# Review Rating: 5
#   Review Time Created: 2020-12-20 21:57:00
#   User Details: {'id': '4RxTUFwMtAKFVw4AJ4TJZA', 'profile_url': 'https://www.yelp.com/user_details?userid=4RxTUFwMtAKFVw4AJ4TJZA', 'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/NkVfWmyLFf_QWtoX2DqDig/o.jpg', 'name': 'Alvina C.'}
#
#
# Business ID: D3tJ-N85kZddAwetQHTpkQ
# Biz URL: https://www.yelp.com/biz/dell-rooster-chicago-chicago?adjust_creative=XhlNVkvJgdCmzrli89R7XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XhlNVkvJgdCmzrli89R7XQ
#
#   Review ID: P0A6EAwHXQxoIZdsE1NEsQ
#   Review URL: https://www.yelp.com/biz/dell-rooster-chicago-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=P0A6EAwHXQxoIZdsE1NEsQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: Food was delicious,  highly recommend. We went for the first time January 27.    We ordered the Milanesa a Caballo - which is Uruguay style breaded chicken,...
# Review Rating: 5
#   Review Time Created: 2024-02-02 10:01:15
#   User Details: {'id': 'Ugt_m6WxqzMT6UzmvHH_oQ', 'profile_url': 'https://www.yelp.com/user_details?userid=Ugt_m6WxqzMT6UzmvHH_oQ', 'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/wbk9IgXb9C04Uicd1Zlg3Q/o.jpg', 'name': 'Lourdes G.'}
#
#
#   Review ID: KmEILmQQ-qUZNgOie8-7Ag
#   Review URL: https://www.yelp.com/biz/dell-rooster-chicago-chicago?adjust_creative=7tVVx3Mq2f8NiAHdvBSKoQ&hrid=KmEILmQQ-qUZNgOie8-7Ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=7tVVx3Mq2f8NiAHdvBSKoQ
#   Review Text: I wish we could say this place was amazing.  I wonder if they had an off night.  We ordered Papa Bravas,  the Paella and Breaded Chicken. It was all salty!...
# Review Rating: 2
#   Review Time Created: 2024-02-28 18:28:32
#   User Details: {'id': 'DTqLlWtsOqvn_nJwBJ9oPg', 'profile_url': 'https://www.yelp.com/user_details?userid=DTqLlWtsOqvn_nJwBJ9oPg', 'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/2WYdDrI7c4GxRB4TPyTmTQ/o.jpg', 'name': 'Jeannie L.'}

# %%
#composite search - using semantic search + scalar search

#define business question
business_question = 'pizza'
business_question_embedding = get_embedding(business_question, model=EMBEDDING_MODEL)

# Search based on chicago_yelp_businesses_reviewed index
business_response = es.search(
    index="chicago_yelp_bussinesses_reviewed",
    knn={
        "field": "chicago_yelp_businesses_vector",
        "query_vector": business_question_embedding,
        "k": 10, 
        "num_candidates": 100
    }
)


# Extract business IDs and names from the business_response
business_info = {hit['_source']['business_id']: hit['_source']['name'] for hit in business_response['hits']['hits']}
business_ids_to_search = list(business_info.keys())


# Define review question
review_question = 'chicago style deep dish pizza'

question_embedding = get_embedding(review_question, model=EMBEDDING_MODEL)
# Search based on chicago_yelp_reviews_per_business index with a range filter on rating
reviews_response = es.search(
    index="chicago_yelp_reviews_per_business",
    body={
        "query": {
            "bool": {
                "must": [
                    {
                        "nested": {
                            "path": "reviews",
                            "query": {
                                "bool": {
                                    "must": [
                                        {"range": {"reviews.rating": {"gt": 4}}},
                                        {"range": {"reviews.time_created": {"gte": "2023-01-01 00:00:00"}}}
                                    ]
                                }
                            }
                        }
                    }
                ]
            }
        },
        "knn": {
            "field": "reviews.content_vector",
            "query_vector": question_embedding,
            "k": 5,
            "num_candidates": 100
        }
    }
)

# Extract business IDs from the reviews response
review_business_ids = [hit['_source']['business_id'] for hit in reviews_response['hits']['hits']]


# Find common business IDs between business_ids_to_search and review_business_ids
common_business_ids = set(business_ids_to_search) & set(review_business_ids)


# Extract and print the reviews for common business IDs along with business names
for hit in reviews_response['hits']['hits']:
    current_business_id = hit['_source']['business_id']
    # Check if the business ID exists in the common_business_ids set
    if current_business_id in common_business_ids:
        business_name = business_info.get(current_business_id, "Business Name Not Available")
        print(f"\nBusiness ID: {current_business_id}")
        print(f"Business Name: {business_name}")
        print(f"Review Text: {hit['_source']['reviews'][0]['text']}")
        print(f"Rating: {hit['_source']['reviews'][0]['rating']}")
        print(f"Review Time Created: {hit['_source']['reviews'][0]['time_created']}")
        print("\n")
# Out:
# Business ID: 511flt1E6niG0sK5FkX_fQ
# Business Name: Five Squared Pizza
# Review Text: With gourmet Detroit-style pizza in a city known for its deep-dish, Five Squared Pizza holds their own weight.
#
# Ordering a small cube shaped pizza over...
# Rating: 5
# Review Time Created: 2024-01-26 12:46:34
#
#
#
# Business ID: YrC3D7DVIQvGVFWBUQw4-w
# Business Name: Chef Ciccio
# Review Text: Amazing Chicago Italian Beef and great service
# We had the beef and potato wedges and finish lunch with an amazing cannoli
# This is a must stop when you are...
# Rating: 5
# Review Time Created: 2023-11-19 13:22:57

# %% [markdown]
# ## Sanity Test:
#
# Execute following commands from the command window/terminal:
#
# **To verify the index got created:**
# - curl -XGET "http://localhost:9200/_cat/indices?v"
#
# **To check the structure of index:**
# - curl -X GET "localhost:9200/chicago_yelp_bussinesses_reviewed?pretty"
# - curl -X GET "localhost:9200/chicago_yelp_reviews_per_business?pretty"
#
# **To check the stats of the index:**
#
# - curl -X GET "localhost:9200/chicago_yelp_bussinesses_reviewed/_stats?pretty"
# - curl -X GET "localhost:9200/chicago_yelp_reviews_per_business/_stats?pretty"
#
#
# ## How to delete  the index?
# **To delete the index you created:**
# - curl -XDELETE "http://localhost:9200/chicago_yelp_bussinesses_reviewed?pretty
# - curl -XDELETE "http://localhost:9200/chicago_yelp_reviews_per_business?pretty
